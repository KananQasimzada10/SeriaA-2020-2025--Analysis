# %%
#Import main lib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import scipy.stats as stats

# %%
#Display max columns

pd.set_option('Display.max_columns', None)

# %%
#Load dataset

df = pd.read_csv('/content/matches_serie_A.csv')

# %%
df.head(5)
# Out:
#        Date   Time     Comp        Round  Day Venue Result  GF  GA  \
# 0  18-08-24  18:30  Serie A  Matchweek 1  Sun  Away      L   0   3
# 1  25-08-24  20:45  Serie A  Matchweek 2  Sun  Home      W   3   0
# 2  31-08-24  20:45  Serie A  Matchweek 3  Sat  Home      W   2   1
# 3  15-09-24  18:00  Serie A  Matchweek 4  Sun  Away      W   4   0
# 4  21-09-24  18:00  Serie A  Matchweek 5  Sat  Away      D   0   0
#
#         Opponent  Poss  Attendance              Captain Formation  \
# 0  Hellas Verona    67     20027.0  Giovanni Di Lorenzo  03-04-03
# 1        Bologna    39     45000.0  Giovanni Di Lorenzo  03-04-03
# 2          Parma    55     50000.0  Giovanni Di Lorenzo  03-04-03
# 3       Cagliari    49     15733.0  Giovanni Di Lorenzo  03-04-03
# 4       Juventus    36     40295.0  Giovanni Di Lorenzo   4-2-3-1
#
#   Opp Formation            Referee  Match Report Notes  Sh  SoT  Dist   FK  \
# 0      03-04-03   Matteo Marchetti  Match Report   NaN  14    4  17.8  0.0
# ...

# %%
df.tail(5)
# Out:
#           Date   Time     Comp         Round  Day Venue Result  GF  GA  \
# 3795  03-05-21  20:45  Serie A  Matchweek 34  Mon  Away      L   0   1
# 3796  09-05-21  15:00  Serie A  Matchweek 35  Sun  Home      L   2   5
# 3797  12-05-21  20:45  Serie A  Matchweek 36  Wed  Away      L   0   1
# 3798  16-05-21  18:00  Serie A  Matchweek 37  Sun  Home      L   1   3
# 3799  22-05-21  20:45  Serie A  Matchweek 38  Sat  Away      L   0   3
#
#        Opponent  Poss  Attendance            Captain Formation Opp Formation  \
# 3795     Torino    49         NaN        Bruno Alves   4-3-1-2       3-1-4-2
# 3796   Atalanta    44         NaN        Bruno Alves   4-1-3-2      03-04-03
# 3797      Lazio    49         NaN  Riccardo Gagliolo  03-05-02      03-05-02
# 3798   Sassuolo    34         NaN        Bruno Alves  03-05-02       4-2-3-1
# 3799  Sampdoria    55         NaN            Hernani  03-05-02      05-03-02
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3800 entries, 0 to 3799
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3800 non-null   object
#  1   Time           3800 non-null   object
#  2   Comp           3800 non-null   object
#  3   Round          3800 non-null   object
#  4   Day            3800 non-null   object
#  5   Venue          3800 non-null   object
#  6   Result         3800 non-null   object
#  7   GF             3800 non-null   int64
#  8   GA             3800 non-null   int64
#  9   Opponent       3800 non-null   object
#  10  Poss           3800 non-null   int64
#  11  Attendance     3116 non-null   float64
#  12  Captain        3800 non-null   object
#  13  Formation      3800 non-null   object
#  14  Opp Formation  3800 non-null   object
#  15  Referee        3800 non-null   object
#  16  Match Report   3800 non-null   object
# ...

# %%
df.describe().T
# Out:
#              count          mean           std     min      25%      50%  \
# GF          3800.0      1.366316      1.191583     0.0      0.0      1.0
# GA          3800.0      1.366316      1.191583     0.0      0.0      1.0
# Poss        3800.0     50.000263     10.345225    18.0     42.0     50.0
# Attendance  3116.0  26559.980745  19448.772172   700.0  12372.0  20707.5
# Sh          3800.0     12.453421      5.197235     0.0      9.0     12.0
# SoT         3800.0      3.980789      2.293174     0.0      2.0      4.0
# Dist        3796.0     17.922366      3.106836     7.3     15.9     17.7
# FK          3798.0      0.444971      0.662395     0.0      0.0      0.0
# PK          3800.0      0.132632      0.361023     0.0      0.0      0.0
# PKatt       3800.0      0.167368      0.405137     0.0      0.0      0.0
# Season      3800.0   2022.998947      1.413655  2021.0   2022.0   2023.0
#
#                   75%      max
# GF              2.000      8.0
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Time                0
# Comp                0
# Round               0
# Day                 0
# Venue               0
# Result              0
# GF                  0
# GA                  0
# Opponent            0
# Poss                0
# Attendance        684
# Captain             0
# Formation           0
# Opp Formation       0
# Referee             0
# Match Report        0
# Notes            3798
# Sh                  0
# SoT                 0
# Dist                4
# FK                  2
# PK                  0
# PKatt               0
# Season              0
# Team                0
# dtype: int64

# %%
df.nunique()
# Out:
# Date              624
# Time               21
# Comp                1
# Round              39
# Day                 7
# Venue               2
# Result              3
# GF                  9
# GA                  9
# Opponent           28
# Poss               61
# Attendance       1359
# Captain           237
# Formation          19
# Opp Formation      18
# Referee            65
# Match Report        1
# Notes               1
# Sh                 36
# SoT                15
# Dist              197
# FK                  6
# PK                  4
# PKatt               4
# Season              5
# Team               28
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Match Report', 'Notes', 'Sh', 'SoT',
#        'Dist', 'FK', 'PK', 'PKatt', 'Season', 'Team'],
#       dtype='object')

# %% [markdown]
# Solve null problems at the dataset

# %%
df.isnull().sum()
# Out:
# Date                0
# Time                0
# Comp                0
# Round               0
# Day                 0
# Venue               0
# Result              0
# GF                  0
# GA                  0
# Opponent            0
# Poss                0
# Attendance        684
# Captain             0
# Formation           0
# Opp Formation       0
# Referee             0
# Match Report        0
# Notes            3798
# Sh                  0
# SoT                 0
# Dist                4
# FK                  2
# PK                  0
# PKatt               0
# Season              0
# Team                0
# dtype: int64

# %%
#Check distribution of data

fig = px.histogram(
                  df,
                   x='Attendance',
                   nbins=30,
                   color_discrete_sequence=['#1f77b4'])

fig.update_layout(
    showlegend=False,
    xaxis_title="Runtime (minutes)",
    yaxis_title="Count",
    bargap=0.1
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Check outliers from the dataset

def outliers(data, column):
    """Detect outliers using IQR method"""
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

len_outliers = {}

for i in df.select_dtypes(include=np.number).columns:
  outliers_iqr = outliers(df, i)
  len_outliers[i] = len(outliers_iqr)

len_outliers
# Out:
# {'GF': 17,
#  'GA': 17,
#  'Poss': 0,
#  'Attendance': 220,
#  'Sh': 46,
#  'SoT': 87,
#  'Dist': 91,
#  'FK': 39,
#  'PK': 476,
#  'PKatt': 590,
#  'Season': 0}

# %%
#Impute with median attendence columns

from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy='median')
df['Attendance'] = impute.fit_transform(df[['Attendance']])

# %% [markdown]
# 1.Delete unnecessary columns from dataset:
#
# •	Unnamed: 0
#
# •	Comp
#
# •	Match Report
#
# •	Notes

# %%
df.drop(columns=['Comp', 'Match Report', 'Notes'], inplace=True)

# %%
df.nunique()
# Out:
# Date              624
# Time               21
# Round              39
# Day                 7
# Venue               2
# Result              3
# GF                  9
# GA                  9
# Opponent           28
# Poss               61
# Attendance       1360
# Captain           237
# Formation          19
# Opp Formation      18
# Referee            65
# Sh                 36
# SoT                15
# Dist              197
# FK                  6
# PK                  4
# PKatt               4
# Season              5
# Team               28
# dtype: int64

# %% [markdown]
# **2.Change some columns**
#
# •	Date column convert to datetime
#
# •	Change Time columns with intervals(1.morning, 2.afternoon, 3.evening)
#
# •	Change Season columns with date.year datatype

# %%
#1.1

df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /tmp/ipython-input-131-347068484.py:3: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
# 1.2

def time_convert(time):
  hour = int(time.split(":")[0])
  if 5<= hour < 12:
    return 'Morning'

  elif 12 <= hour < 18:
    return 'Afternoon'

  else:
    return 'Evening'

df['time_interval'] = df['Time'].apply(time_convert)

# %%
df['Result'] = df['Result'].replace({'W': 'Win', 'D': 'Draw', 'L': 'Lose'})

# %%
df['Result'].unique()
# Out:
# array(['Lose', 'Win', 'Draw'], dtype=object)

# %%
df.head(5)
# Out:
#         Date   Time        Round  Day Venue Result  GF  GA       Opponent  \
# 0 2024-08-18  18:30  Matchweek 1  Sun  Away   Lose   0   3  Hellas Verona
# 1 2024-08-25  20:45  Matchweek 2  Sun  Home    Win   3   0        Bologna
# 2 2024-08-31  20:45  Matchweek 3  Sat  Home    Win   2   1          Parma
# 3 2024-09-15  18:00  Matchweek 4  Sun  Away    Win   4   0       Cagliari
# 4 2024-09-21  18:00  Matchweek 5  Sat  Away   Draw   0   0       Juventus
#
#    Poss  Attendance              Captain Formation Opp Formation  \
# 0    67     20027.0  Giovanni Di Lorenzo  03-04-03      03-04-03
# 1    39     45000.0  Giovanni Di Lorenzo  03-04-03      04-03-03
# 2    55     50000.0  Giovanni Di Lorenzo  03-04-03       4-2-3-1
# 3    49     15733.0  Giovanni Di Lorenzo  03-04-03      03-04-03
# 4    36     40295.0  Giovanni Di Lorenzo   4-2-3-1       4-2-3-1
#
#              Referee  Sh  SoT  Dist   FK  PK  PKatt  Season    Team  \
# ...

# %% [markdown]
# # ****4.Find per year attendance count****

# %%
attendence = df.groupby('Season')['Attendance'].sum()
attendence
# Out:
# Season
# 2021    14020544.0
# 2022    13786636.0
# 2023    22402047.0
# 2024    23463560.0
# 2025    23252043.0
# Name: Attendance, dtype: float64

# %%
fig = px.bar(
    x=attendence.index,
    y=attendence.values,
    title='Attendence by years',
    labels={'x':'Season', 'y':'Count of attendence'},
    color=attendence.values,
    color_continuous_scale='viridis'
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(
              x=attendence.index,
              y=attendence.values,
              title='Attendence by years',
              markers=True)

fig.update_traces(line_color='#1f77b4', line_width=3)
fig.update_layout(hovermode='x unified')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #4.1 Find attendance as time interval(Morning, afternoon, evening)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt',
#        'Season', 'Team', 'time_interval'],
#       dtype='object')

# %%
df.time_interval.unique()
# Out:
# array(['Evening', 'Afternoon'], dtype=object)

# %%
time_attendence = df.groupby(['Season', 'time_interval'])['Attendance'].sum().reset_index()
time_attendence.tail(10)
# Out:
#    Season time_interval  Attendance
# 0    2021     Afternoon   5958345.0
# 1    2021       Evening   8062199.0
# 2    2022     Afternoon   3487754.0
# 3    2022       Evening  10298882.0
# 4    2023     Afternoon   5376532.0
# 5    2023       Evening  17025515.0
# 6    2024     Afternoon   6058073.0
# 7    2024       Evening  17405487.0
# 8    2025     Afternoon   5456232.0
# 9    2025       Evening  17795811.0

# %%
fig = px.line(time_attendence,
              x='Season',
              y='Attendance',
              color='time_interval',  # Differentiate by 'time_interval' (Morning, Afternoon, Evening)
              title='Total Attendance by Season and Time Interval',
              markers=True)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###5.Find counts of days for per year

# %%
day1 = df.groupby(['Season', 'Day'])['Day'].size()
day1
# Out:
# Season  Day
# 2021    Fri     28
#         Mon     36
#         Sat    208
#         Sun    352
#         Thu     10
#         Tue     16
#         Wed    110
# 2022    Fri     46
#         Mon     64
#         Sat    214
#         Sun    334
#         Thu     26
#         Tue     26
#         Wed     50
# 2023    Fri     54
#         Mon     84
#         Sat    218
#         Sun    318
#         Thu     12
#         Tue     20
#         Wed     56
# 2024    Fri     80
#         Mon     92
#         Sat    242
#         Sun    312
#         Thu     12
#         Tue      4
#         Wed     18
# 2025    Fri     62
#         Mon     80
#         Sat    232
#         Sun    344
#         Thu     10
#         Tue     12
#         Wed     18
# Name: Day, dtype: int64

# %%
day1_df = df.groupby(['Season', 'Day']).size().reset_index(name='Count')


fig = px.bar(
    day1_df,
    x='Day',
    y='Count',
    title='Count of games by day per season',
    labels={'Day':'Day of the week', 'Count':'Number of games'},
    color='Day',
    facet_col='Season', #Print each season seperatly
    color_continuous_scale='viridis'
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #**6.Find distribution of game(W, L, D) statistics**
#
# •	Also find same thing for 3 main clubs

# %%
fig = px.pie(df,
             names='Result',
             title='Distribution of Match Results by Season',
             color='Result',
             color_discrete_map={'Win': 'green', 'Lose': 'red', 'Draw': 'gray'},
             facet_col='Season')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
team_name = 'Napoli'
team_df = df[df['Team'] == team_name]


fig = px.pie(team_df,
             names='Result',
             title=f'Distribution of Match Results for {team_name} by Season',
             color='Result',
             color_discrete_map={'Win': 'green', 'Lose': 'red', 'Draw': 'gray'},
             facet_col='Season',
            facet_col_spacing=0.1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.Team.unique()
# Out:
# array(['Napoli', 'Internazionale', 'Atalanta', 'Juventus', 'Roma',
#        'Fiorentina', 'Lazio', 'Milan', 'Bologna', 'Como', 'Torino',
#        'Udinese', 'Genoa', 'Hellas Verona', 'Cagliari', 'Parma', 'Lecce',
#        'Empoli', 'Venezia', 'Monza', 'Frosinone', 'Sassuolo',
#        'Salernitana', 'Spezia', 'Cremonese', 'Sampdoria', 'Benevento',
#        'Crotone'], dtype=object)

# %%
df_Juventus = df[df['Team'] == 'Juventus']

fig = px.pie(
             df_Juventus,
             names='Result',
             title=f'Distribution of Match Results for Juventus by Season',
             color='Result',
             color_discrete_map={'Win': 'green', 'Lose': 'red', 'Draw': 'gray'},
             facet_col='Season',
             facet_col_spacing=0.1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_Milan = df[df['Team'] == 'Milan']

fig = px.pie(
    df_Milan,
    names='Result',
    title=f'Distribution of Match Results for Juventus by Season',
    color='Result',
    color_discrete_map={'Win': 'green', 'Lose': 'red', 'Draw': 'gray'},
    facet_col='Season',
    facet_col_spacing=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **7.**
#
# **•	Find top 5 club which they won a lot per year**
#
# **•	Find top 5 club which they lost a lot per year**

# %%
#7.1

win_df = df[df['Result'] == 'Win']
wins_per_season = win_df.groupby(['Season', 'Team']).size().reset_index(name='Wins')
top_wins_per_year = wins_per_season.sort_values(by=['Season', 'Wins'], ascending=[True, False])
top_wins_per_year
# Out:
#     Season            Team  Wins
# 8     2021  Internazionale    28
# 11    2021           Milan    24
# 12    2021          Napoli    24
# 0     2021        Atalanta    23
# 9     2021        Juventus    23
# ..     ...             ...   ...
# 91    2025           Lecce     8
# 95    2025           Parma     7
# 84    2025          Empoli     6
# 99    2025         Venezia     5
# 93    2025           Monza     3
#
# [100 rows x 3 columns]

# %%
top_teams_per_season = wins_per_season.groupby('Season').apply(lambda x: x.nlargest(5, 'Wins')).reset_index(drop=True)
top_teams_per_season
# Out:
# /tmp/ipython-input-151-2219922538.py:1: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#     Season            Team  Wins
# 0     2021  Internazionale    28
# 1     2021           Milan    24
# 2     2021          Napoli    24
# 3     2021        Atalanta    23
# 4     2021        Juventus    23
# 5     2022           Milan    26
# 6     2022  Internazionale    25
# 7     2022          Napoli    24
# 8     2022        Juventus    20
# 9     2022      Fiorentina    19
# 10    2023          Napoli    28
# 11    2023  Internazionale    23
# 12    2023        Juventus    22
# 13    2023           Lazio    22
# 14    2023           Milan    20
# 15    2024  Internazionale    29
# ...

# %%
fig = px.bar(
    top_teams_per_season,
    x='Team',
    y='Wins',
    title='Count of wins last 5 years top 5 teams',
    color='Team',
    facet_col='Season', #Print each season seperatly
    color_continuous_scale='viridis'
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#7.2

lost_df = df[df['Result'] == 'Lose']
lost_per_seoson = lost_df.groupby(['Season', 'Team']).size().reset_index(name='Losts')
top_lost_per_seoson = lost_per_seoson.sort_values(by=['Season', 'Losts'], ascending=[False, False])

# %%
top_lost_per_seoson1 = top_lost_per_seoson.groupby('Season').apply(lambda x: x.nsmallest(5, 'Losts')).reset_index(drop=True)
# Out:
# /tmp/ipython-input-154-800130107.py:1: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
fig = px.bar(
    top_lost_per_seoson1,
    x='Team',
    y='Losts',
    title='Count of lost last 5 years top 5 teams',
    color='Team',
    facet_col='Season', #Print each season seperatly
    color_continuous_scale='viridis'
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 8.Total count of goal per season
#
# •	Find total gol for each match
#
# •	After find total count

# %%
df['total_gol'] = df['GF'] + df['GA']

total_goal_statistcs = df.groupby('Season')['total_gol'].sum().reset_index()
total_goal_statistcs = total_goal_statistcs.sort_index(ascending=True)
total_goal_statistcs
# Out:
#    Season  total_gol
# 0    2021       2326
# 1    2022       2178
# 2    2023       1956
# 3    2024       1984
# 4    2025       1940

# %%
total_goal_statistcs['Season'] = total_goal_statistcs['Season'].astype(str)

line_fig = px.line(total_goal_statistcs,
                   x='Season',
                   y='total_gol',
                   title='Total Goals per Season (Line Chart)',
                   markers=True)

bar_fig = px.bar(total_goal_statistcs,
                 x='Season',
                 y='total_gol',
                 title='Total Goals per Season (Bar Chart)',
                 color='Season')

line_fig.show()
bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_5_team_gf = df.groupby('Team')['GF'].sum().reset_index()
top_5_team_gf = top_5_team_gf.nlargest(5, 'GF')
top_5_team_gf
# Out:
#               Team   GF
# 12  Internazionale  412
# 0         Atalanta  371
# 18          Napoli  351
# 16           Milan  344
# 14           Lazio  308

# %%
bar_fig = px.bar(
                 top_5_team_gf,
                 x='Team',
                 y='GF',
                 title='Top 5 club as GF',
                 color='Team')

bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
last_5_team_gf = df.groupby('Team')['GF'].sum().reset_index()
last_5_team_gf = last_5_team_gf.nsmallest(5, 'GF')
last_5_team_gf
# Out:
#         Team  GF
# 5  Cremonese  36
# 1  Benevento  40
# 9  Frosinone  44
# 6    Crotone  45
# 4       Como  49

# %%
bar_fig = px.bar(
                 last_5_team_gf,
                 x='Team',
                 y='GF',
                 title='Last 5 club as GF',
                 color='Team')

bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_5_ga = df.groupby("Team")['GA'].sum().reset_index()
top_5_ga = top_5_ga.nlargest(5, 'GA')
top_5_ga
# Out:
#              Team   GA
# 11  Hellas Verona  284
# 26        Udinese  273
# 23       Sassuolo  258
# 3        Cagliari  251
# 2         Bologna  248

# %%
bar_fig = px.bar(
                 top_5_ga,
                 x='Team',
                 y='GA',
                 title='Top 5 club as GA',
                 color='Team')

bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
last_5_ga = df.groupby("Team")['GA'].sum().reset_index()
last_5_ga = last_5_ga.nsmallest(5, 'GA')
last_5_ga
# Out:
#         Team  GA
# 4       Como  52
# 5  Cremonese  69
# 9  Frosinone  69
# 1  Benevento  75
# 6    Crotone  92

# %%
bar_fig = px.bar(
                 last_5_ga,
                 x='Team',
                 y='GA',
                 title='Last 5 club as GA',
                 color='Team')

bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt',
#        'Season', 'Team', 'time_interval', 'total_gol'],
#       dtype='object')

# %%
top_ref_5 = df.groupby('Referee').size().reset_index(name='count')
top_ref_5  = top_ref_5.nlargest(5, 'count')
top_ref_5
# Out:
#              Referee  count
# 9     Daniele Doveri    164
# 17      Davide Massa    160
# 54  Maurizio Mariani    160
# 8     Daniele Chiffi    146
# 44    Marco Di Bello    142

# %%
bar_fig = px.bar(
    top_ref_5,
    x='Referee',
    y='count',
    title='Top 5 Referee',
    color='Referee',
    color_discrete_sequence=px.colors.qualitative.Bold
)

bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_int = df.select_dtypes(include=np.number)

corr = df_int.corr()

fig = px.imshow(
    corr,
    x=corr.columns.values,
    y=corr.columns.values,
    color_continuous_scale='Viridis',
    title='Correlation Heatmap',
    text_auto=True
)

fig.update_layout(
    xaxis_title='Variables',
    yaxis_title='Variables'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = px.scatter(df,
                  x='Sh',
                  y='GF',
                  title='Shots vs Goals Scored (GF)',
                  labels={'Sh': 'Shots', 'GF': 'Goals Scored'},
                  facet_col='Season',
                  color='Season')

# Scatter Plot: Shots vs Shots on Target (SoT)
fig2 = px.scatter(df,
                  x='Sh',
                  y='SoT',
                  title='Shots vs Shots on Target (SoT)',
                  labels={'Sh': 'Shots', 'SoT': 'Shots on Target'},
                  facet_col='Season',
                  color='Season')

# Scatter Plot: Goals Scored (GF) vs Goals Conceded (GA)
fig3 = px.scatter(df,
                  x='GF',
                  y='GA',
                  title='Goals Scored (GF) vs Goals Conceded (GA)',
                  labels={'GF': 'Goals Scored', 'GA': 'Goals Conceded'},
                  facet_col='Season',
                  color='Season')

# Scatter Plot: Shots on Target (SoT) vs Distance (Dist)
fig4 = px.scatter(df,
                  x='SoT',
                  y='Dist',
                  title='Shots on Target (SoT) vs Distance',
                  labels={'SoT': 'Shots on Target', 'Dist': 'Distance'},
                  facet_col='Season',
                  color='Season')

# Show the figures
fig1.show()
fig2.show()
fig3.show()
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Task 13

df['Shot Percent'] = (df['GF'] / df['Sh']) * 100

shot_top_5 = df.groupby('Team')['Shot Percent'].mean().reset_index(name='percent').nlargest(5, 'percent')
shot_top_5
# Out:
#               Team    percent
# 12  Internazionale  15.382300
# 14           Lazio  13.923130
# 0         Atalanta  13.723918
# 6          Crotone  13.503358
# 18          Napoli  13.455991

# %%
bar_fig = px.bar(
    shot_top_5,
    x='Team',
    y='percent',
    title='Top 5 Percent team',
    color='Team',
    color_discrete_sequence=px.colors.qualitative.Bold
)

bar_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt',
#        'Season', 'Team', 'time_interval', 'total_gol', 'Cluster',
#        'Shot Percent', 'Penalty Percent'],
#       dtype='object')

# %%
shot_top_5_by_season = df.groupby(['Season', 'Team'])['Shot Percent'].mean().reset_index(name='percent')
shot_top_5_by_season = shot_top_5_by_season.groupby('Season').apply(lambda x: x.nlargest(5, 'percent')).reset_index(drop=True)

shot_top_5_by_season
# Out:
# /tmp/ipython-input-193-931796351.py:5: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#     Season            Team    percent
# 0     2021  Internazionale  17.773282
# 1     2021          Spezia  16.561860
# 2     2021        Juventus  16.509604
# 3     2021          Napoli  16.196075
# 4     2021           Milan  16.163078
# 5     2022   Hellas Verona  18.594755
# 6     2022           Lazio  17.753927
# 7     2022          Napoli  14.598920
# 8     2022  Internazionale  13.629935
# 9     2022        Juventus  13.278715
# 10    2023     Salernitana  14.724389
# 11    2023           Monza  14.380155
# 12    2023           Lazio  14.245175
# 13    2023        Atalanta  13.984960
# ...

# %%
shot_top_5_by_season['Season'] = shot_top_5_by_season['Season'].astype(str)

# Create a line plot for Shot Percent of the top 5 teams across seasons, treated as a time series
fig = px.line(shot_top_5_by_season,
              x='Season',
              y='percent',
              color='Team',  # Different color for each team
              title='Shot Percent Time Series for Top 5 Teams by Season',
              labels={'percent': 'Shot Percent (%)', 'Season': 'Season', 'Team': 'Team'},
              markers=True)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Chi testing 13

contingency_table = pd.crosstab(df['Venue'], df['Result'])

chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected frequencies table:\n{expected}")

if p < 0.05:
    print("Reject the null hypothesis: There is a significant difference between home and away wins.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between home and away wins.")
# Out:
# Chi2 Statistic: 37.87012987012987
# P-value: 5.978686541101694e-09
# Degrees of Freedom: 2
# Expected frequencies table:
# [[514. 693. 693.]
#  [514. 693. 693.]]
# Reject the null hypothesis: There is a significant difference between home and away wins.

# %%
#Anove testing 14

anova_result = stats.f_oneway(
    df[df['Season'] == 2021]['GF'],
    df[df['Season'] == 2022]['GF'],
    df[df['Season'] == 2023]['GF'],
    df[df['Season'] == 2024]['GF'],
    df[df['Season'] == 2025]['GF']
)

print(f"ANOVA F-statistic: {anova_result.statistic}")
print(f"P-value: {anova_result.pvalue}")

if anova_result.pvalue < 0.05:
    print("Reject the null hypothesis: There is a significant difference in goals scored across seasons.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in goals scored across seasons.")
# Out:
# ANOVA F-statistic: 6.6506979425348955
# P-value: 2.4887874962014327e-05
# Reject the null hypothesis: There is a significant difference in goals scored across seasons.
